# %% [markdown]
# # 4.10 Coding Etiquette and Excel Reporting

# %% [markdown]
# ### Part 1: Task

# %%
## Import the packages required for the data analysis

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## Importing the data set required for the analysis

path = r'/Users/balachandark/Desktop/Instacart Basket Analysis'
ords_prods_customer = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_customer.pkl'))

# %%
## Checking the columns

ords_prods_customer.head()
# Out:
#     order_id  user_id evaluation_set  order_number  orders_day_of_week  \
# 0  2539329.0      1.0          prior           1.0                   2
# 1  2539329.0      1.0          prior           1.0                   2
# 2  2539329.0      1.0          prior           1.0                   2
# 3  2539329.0      1.0          prior           1.0                   2
# 4  2539329.0      1.0          prior           1.0                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    reordered  ...        order_freq_flag  first_name  surname  gender  \
# 0          0  ...  Non-frequent customer       Linda   Nguyen  Female
# 1          0  ...  Non-frequent customer       Linda   Nguyen  Female
# 2          0  ...  Non-frequent customer       Linda   Nguyen  Female
# 3          0  ...  Non-frequent customer       Linda   Nguyen  Female
# 4          0  ...  Non-frequent customer       Linda   Nguyen  Female
#
#      state age  date_joined no_of_dependants  family_status income
# 0  Alabama  31    2/17/2019                3        married  40423
# 1  Alabama  31    2/17/2019                3        married  40423
# 2  Alabama  31    2/17/2019                3        married  40423
# 3  Alabama  31    2/17/2019                3        married  40423
# 4  Alabama  31    2/17/2019                3        married  40423
#
# [5 rows x 31 columns]

# %% [markdown]
# ##### **Q2: Dropping the name columns as they can data identification threat.**

# %%
## Drop name columns

ords_prods_customer = ords_prods_customer.drop(['first_name', 'surname'], axis = 1)

# %%
ords_prods_customer.columns
# Out:
# Index(['order_id', 'user_id', 'evaluation_set', 'order_number',
#        'orders_day_of_week', 'order_hour_of_day', 'days_since_prior_order',
#        'product_id', 'add_to_cart_order', 'reordered', 'product_name',
#        'aisle_id', 'department_id', 'prices', 'busiest_day',
#        'busiest_period_of_day', 'max_order', 'loyalty_flag',
#        'spending_behavior', 'spending_flag', 'order_frequent',
#        'order_freq_flag', 'gender', 'state', 'age', 'date_joined',
#        'no_of_dependants', 'family_status', 'income'],
#       dtype='object')

# %%
## Renaming the family status column to marital status

ords_prods_customer = ords_prods_customer.rename(columns = {'family_status':'marital_status'})

# %% [markdown]
# ##### **Q3.1: Regional segmentation of the data**

# %%
## Creating regions based on the state column

def create_region(x):
    if x in ['Maine', 'New Hampshire', 'Vermont', 'Massachusetts', 'Rhode Island', 'Connecticut', 'New York', 'Pennsylvania', 'New Jersey']:
        return 'Northeast'
    elif x in ['Wisconsin','Michigan','Illinois','Indiana','Ohio','North Dakota','South Dakota','Nebraska','Kansas','Minnesota','Iowa','Missouri']:
        return 'Midwest'
    elif x in ['Delaware','Maryland','District of Columbia','Virginia',
                   'West Virginia','North Carolina','South Carolina','Georgia','Florida','Kentucky',
                   'Tennessee','Mississippi','Alabama','Oklahoma','Texas','Arkansas','Louisiana']:
        return 'East South Central'
    else:
        return 'West'

# %%
## Creating the region column
ords_prods_customer['region'] = ords_prods_customer['state'].apply(create_region)

# %% [markdown]
# ##### **Q3.2: Relationship between spending and regions**

# %%
pd.crosstab(ords_prods_customer['region'], ords_prods_customer['spending_flag'])
# Out:
# spending_flag       High spender  Low spender
# region
# East South Central        209691     10582194
# Midwest                   155975      7441350
# Northeast                 108225      5614511
# West                      160354      8132559

# %% [markdown]
# ##### **Q4: Creating exclusion flag**

# %%
ords_prods_customer['total_order'] = ords_prods_customer.groupby(['user_id'])['order_number'].transform('sum')

ords_prods_customer.loc[ords_prods_customer['total_order'] >= 5, 'exclusion_flag'] = 'high-actitvity customer'
ords_prods_customer.loc[(ords_prods_customer['total_order'] < 5), 'exclusion_flag'] = 'low-activity customer'

ords_prods_customer.shape
# Out:
# (32404859, 32)

# %%
## Removing the customers with low-activity flag

ords_prods_customer = ords_prods_customer[ords_prods_customer['exclusion_flag'] == 'high-actitvity customer']

## checking the shape of the new data frame

ords_prods_customer.shape
# Out:
# (32404856, 32)

# %% [markdown]
# ##### Using the exclusion flag, we remove 3 customers.

# %% [markdown]
# ##### **Q5: Customer profiling**

# %%
## Creating customer profiles

ords_prods_customer['age'].min() ## minimum age is 18
# Out:
# 18

# %%
ords_prods_customer['age'].max() ## maximum age is 81
# Out:
# 81

# %%
## Number of dependents

ords_prods_customer['no_of_dependants'].min()
# Out:
# 0

# %%
ords_prods_customer['no_of_dependants'].max()
# Out:
# 3

# %%
ords_prods_customer['no_of_dependants'].value_counts()
# Out:
# no_of_dependants
# 3    8135109
# 0    8097502
# 2    8091141
# 1    8081104
# Name: count, dtype: int64

# %%
## Creating age profile

ords_prods_customer.loc[(ords_prods_customer['age'] < 25), 'age_category'] = 'young adult'
ords_prods_customer.loc[(ords_prods_customer['age'] >= 25) & (ords_prods_customer['age'] < 40), 'age_category'] = 'adult'
ords_prods_customer.loc[(ords_prods_customer['age'] >= 40) & (ords_prods_customer['age'] <= 60), 'age_category'] = 'middle age'
ords_prods_customer.loc[(ords_prods_customer['age'] > 60), 'age_category'] = 'elderly'

# %%
## Checking the age profile categories

ords_prods_customer['age_category'].value_counts()
# Out:
# age_category
# middle age     10657828
# elderly        10582836
# adult           7591191
# young adult     3573001
# Name: count, dtype: int64

# %%
## Creating dependent profile

ords_prods_customer.loc[(ords_prods_customer['no_of_dependants']) == 0, 'dependant_category'] = 'single'
ords_prods_customer.loc[(ords_prods_customer['no_of_dependants']) > 0, 'dependant_category'] = 'family'

# %%
## Checking the dependent category

ords_prods_customer['dependant_category'].value_counts()
# Out:
# dependant_category
# family    24307354
# single     8097502
# Name: count, dtype: int64

# %%
## Creating department category based on the department id
## Department category information were obtained from Kaggle website

ords_prods_customer.loc[(ords_prods_customer['department_id']) == 1, 'department_category'] = 'frozen'
ords_prods_customer.loc[(ords_prods_customer['department_id']) == 2, 'department_category'] = 'other'
ords_prods_customer.loc[(ords_prods_customer['department_id']) == 3, 'department_category'] = 'bakery'
ords_prods_customer.loc[(ords_prods_customer['department_id']) == 4, 'department_category'] = 'produce'
ords_prods_customer.loc[(ords_prods_customer['department_id']) == 5, 'department_category'] = 'alcohol'
ords_prods_customer.loc[(ords_prods_customer['department_id']) == 6, 'department_category'] = 'international'
ords_prods_customer.loc[(ords_prods_customer['department_id']) == 7, 'department_category'] = 'beverages'
ords_prods_customer.loc[(ords_prods_customer['department_id']) == 8, 'department_category'] = 'pets'
ords_prods_customer.loc[(ords_prods_customer['department_id']) == 9, 'department_category'] = 'dry goods pasta'
ords_prods_customer.loc[(ords_prods_customer['department_id']) == 10, 'department_category'] = 'bulk'

# %%
## Creating income categories of customers
## Income categories are created based on the quantile information

ords_prods_customer.loc[(ords_prods_customer['income']) < 67004.0, 'income_category'] = 'low income'
ords_prods_customer.loc[(ords_prods_customer['income'] >= 67004.0) & (ords_prods_customer['income'] <= 96618.0), 'income_category'] = 'lower mid income'
ords_prods_customer.loc[(ords_prods_customer['income'] >= 96618.0) & (ords_prods_customer['income'] <= 127912.0), 'income_category'] = 'higher mid income'
ords_prods_customer.loc[(ords_prods_customer['income']) > 127912.0, 'income_category'] = 'high income'

ords_prods_customer['income_category'].value_counts()
# Out:
# income_category
# higher mid income    8101400
# low income           8101212
# lower mid income     8101207
# high income          8101037
# Name: count, dtype: int64

# %% [markdown]
# ##### Combination of multiple variables to create a customer profile will increase number of categories leading to confusion. Hence, the charts are produced with the profiles created based on one variables. The visualization will be produced for each of the customer profiles on the ordering behavior, expenditures, and answering key question of Instacart.

# %% [markdown]
# ##### Customer profiles created
# #####      1. Age categories
# #####      2. Dependant categories
# #####      3. Department categories
# #####      4. Income categories

# %% [markdown]
# ##### **Q6: Visualization to show distribution of profiles**
# ##### Importance given to visuals addressing the key questions in the project brief

# %%
## Profile based visuals: Age categories
## Who orders the most? 
df_ordering_age = ords_prods_customer.groupby('age_category')['order_id'].count()

## Bar chart to show the differences in the ordering behavior of the customers

plt.bar(df_ordering_age.index, df_ordering_age.values, color = 'lightgreen', edgecolor = 'black')
plt.xlabel('Age Category')
plt.ylabel('Number of Orders')
plt.title('Ordering Behavior by Age Category',
         pad = 30,
         fontsize=15,
         fontweight=2)
plt.xticks(rotation=45);

plt.savefig(os.path.join(path, '04 Analysis','Visualizations', 'ordering_behavior_age.png'), bbox_inches='tight')

# %%
## Is there a difference in the expenditure behavior of people with dependants? 

ords_prods_customer.groupby('dependant_category')['prices'].mean().plot.bar(color=['blue','red'], edgecolor='black')
plt.xticks(rotation=45)
plt.title('Ordering behavior of customers - Average Expenditure', 
          pad = 30,
         fontsize=15,
         fontweight=2)
plt.suptitle('(with or without dependents)',
            x=0.5,
            y=0.93)
plt.ylabel('Average Price');

plt.savefig(os.path.join(path, '04 Analysis','Visualizations', 'ordering_behavior_expenditure.png'), bbox_inches='tight')

# %%
## What are the top 5 ordered products over the weekends? 
#  0 = Saturday, 1 = Sunday

# Filter only weekend orders
df_weekend = ords_prods_customer[ords_prods_customer['orders_day_of_week'].isin([0, 1])]

# Creating proportion information
df_weekend_plot = df_weekend['department_category'].value_counts(normalize=True)
df_weekend_plot = df_weekend_plot.reset_index()
df_weekend_plot.columns = ['department_category', 'proportion']

## Selecting the top 5 categories

df_weekend_plot = df_weekend_plot[df_weekend_plot['proportion'] > 0.016194]
my_explode = [0.2,0,0,0,0]
colors = ['green', 'red', 'yellow', 'indigo', 'lightblue']
## Creating a pie chart 
plt.pie(df_weekend_plot['proportion'], labels=df_weekend_plot['department_category'], 
        explode = my_explode, 
        autopct='%.1f%%', shadow = True, 
        colors = colors,
        labeldistance=1.1)
plt.title('Top 5 products sold over weekends', 
          pad = 30,
         fontsize=20,
         fontweight=2);

plt.savefig(os.path.join(path, '04 Analysis','Visualizations', 'top_5_sold_over_weekend.png'), bbox_inches='tight')

# %%
## On which day and which department gets most of the orders

ords_prods_customer.loc[(ords_prods_customer['orders_day_of_week']) == 0, 'ordering_day'] = 'Saturday'
ords_prods_customer.loc[(ords_prods_customer['orders_day_of_week']) == 1, 'ordering_day'] = 'Sunday'
ords_prods_customer.loc[(ords_prods_customer['orders_day_of_week']) == 2, 'ordering_day'] = 'Monday'
ords_prods_customer.loc[(ords_prods_customer['orders_day_of_week']) == 3, 'ordering_day'] = 'Tuesday'
ords_prods_customer.loc[(ords_prods_customer['orders_day_of_week']) == 4, 'ordering_day'] = 'Wednesday'
ords_prods_customer.loc[(ords_prods_customer['orders_day_of_week']) == 5, 'ordering_day'] = 'Thursday'
ords_prods_customer.loc[(ords_prods_customer['orders_day_of_week']) == 6, 'ordering_day'] = 'Friday'



# Create the crosstab
df_test = pd.crosstab(ords_prods_customer['ordering_day'], 
                       ords_prods_customer['department_category'])
day_order = ["Saturday", "Sunday", "Monday", "Tuesday", "Wednesday", "Thursday", "Friday"]
df_test = df_test.reindex(day_order)


df_test.plot(kind='bar', stacked=True, edgecolor = 'black')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), ncol=1, fancybox=False, shadow=True)
plt.xticks(rotation = 45)

plt.title('Busy days in a week', 
          pad = 25,
          fontsize=15,
         fontweight=2);
plt.suptitle('(by department)',
            x=0.5,
            y=0.93)
plt.savefig(os.path.join(path, '04 Analysis','Visualizations', 'busy_days.png'), bbox_inches='tight')

# %%
## Combining two customer profiles to create a new one
## To reduce the complexity, let's create profile with income and then number of dependents

## Classifying income based on the median levels: 
# Anyone below the median income is low income holder
# above the median income is high income holder
ords_prods_customer.loc[(ords_prods_customer['income']) < 96618, 'two_level_income_category'] = 'low income'
ords_prods_customer.loc[(ords_prods_customer['income']) > 96618, 'two_level_income_category'] = 'high income'

## Combining the income category with the dependents category

ords_prods_customer['customer_profile'] = ords_prods_customer['dependant_category'] + " " + ords_prods_customer['two_level_income_category']

## Checking the column

ords_prods_customer['customer_profile'].value_counts()
# Out:
# customer_profile
# family low income     12173670
# family high income    12133485
# single high income     4068753
# single low income      4028749
# Name: count, dtype: int64

# %%
## Plot to show the distribution of the created customer profile
df_pie_plot = ords_prods_customer['customer_profile'].value_counts().reset_index()
df_pie_plot.columns=['customer_profile','total_numbers']

plt.pie(df_pie_plot['total_numbers'], labels=df_pie_plot['customer_profile'], 
        autopct='%.1f%%', shadow = True, 
        colors = colors,
        labeldistance=1.1)
plt.title('Customer profile distribution', 
          pad = 30,
         fontsize=15,
         fontweight=2);

plt.savefig(os.path.join(path, '04 Analysis','Visualizations', 'customer_profile_distribution.png'), bbox_inches='tight')

# %% [markdown]
# ##### **Q7: Aggregate the max, min, and mean - usage frequency and expenditure**

# %%
## Creating the expenditure and order frequency based on age categories

ords_prods_customer.groupby('age_category').agg( {'prices':['mean','min','max'],
                                                 'order_id':['mean','min','max']})
# Out:
#                  prices                    order_id
#                    mean  min      max          mean  min        max
# age_category
# adult         11.896113  1.0  99999.0  1.711507e+06  5.0  3421076.0
# elderly       11.845924  1.0  99999.0  1.710022e+06  4.0  3421083.0
# middle age    12.026352  1.0  99999.0  1.710777e+06  2.0  3421081.0
# young adult   12.419133  1.0  99999.0  1.711177e+06  8.0  3421077.0

# %% [markdown]
# ##### **Q8.1: Customer profiles with Departments - identify the link**

# %%
## Compare your customer profiles with regions and departments. Can you identify a link between them? 
## Customers may demonstrate different behaviors across regions, which could make this information important.
## What the most preferred department (products) by the customers

df_depart_cust = pd.crosstab(ords_prods_customer['customer_profile'], ords_prods_customer['department_category'])
df_depart_cust
# Out:
# department_category  alcohol  bakery  beverages   bulk  dry goods pasta  \
# customer_profile
# family high income     57931  448861     958998  12138           338734
# family low income      56647  429162    1054675  14157           312616
# single high income     20787  151825     322978   3957           112095
# single low income      18331  142580     351464   4321           103167
#
# department_category  frozen  international  other   pets  produce
# customer_profile
# family high income   846993         102995  13591  37899  3610395
# family low income    830573          98544  13525  35234  3493366
# single high income   283145          34959   4586  13531  1217798
# single low income    274015          32754   4589  11052  1157646

# %%
## Department category visual
df_depart_cust.plot.barh(stacked=False, edgecolor = 'black', width=0.8);
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), ncol=1, fancybox=False, shadow=True)
plt.title('Customer profile product preferences', 
          pad = 40,
          fontsize=15,
         fontweight=2);
plt.ylabel('Customer Profile');

plt.savefig(os.path.join(path, '04 Analysis','Visualizations', 'customer_profile_prod_pref.png'), bbox_inches='tight')

# %% [markdown]
# ##### **Q8.2: Customer profiles with Regions - identify the link**

# %%
## Side by side bar chart to show the distribution of region and customer profiles

df_region = pd.crosstab(ords_prods_customer['customer_profile'], ords_prods_customer['region'], normalize = True)
df_region

df_region.plot.bar(stacked=False, edgecolor = 'black')
plt.title('Distribution of Region and Customer Profiles', 
          pad = 40,
          fontsize=15,
          fontweight=2);
plt.ylabel('Distribution percentage')
plt.xlabel('Customer Profile')
plt.xticks(rotation = 45);

plt.savefig(os.path.join(path, '04 Analysis','Visualizations', 'region_and_customer_profile.png'), bbox_inches='tight')

# %% [markdown]
# ### Answering the key questions

# %%
## Key question 1: Busiest days of the week

# The sales team needs to know what the busiest days of the week and hours of the
# day are (i.e., the days and times with the most orders) in order to schedule ads at
# times when there are fewer orders.

## Line chart

day_order = ['Saturday', 'Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']
ords_prods_customer.loc[:, 'ordering_day'] = pd.Categorical(ords_prods_customer['ordering_day'], categories=day_order, ordered=True)

ords_prods_customer['ordering_day'].value_counts().reindex(day_order).plot.bar(color='#f57842', edgecolor='black')

plt.title('Busiest days in a week', pad=25, fontsize=15, fontweight=2)
plt.suptitle('(by total orders)', x=0.5, y=0.93)
plt.xlabel('Days of the Week')
plt.ylabel('Count of Orders')
plt.xticks(rotation=45)

plt.savefig(os.path.join(path, '04 Analysis','Visualizations', 'busiest_days_in_a_week.png'), bbox_inches='tight')

# %%
## Key question 1.2: Busiest hours of the day

# The sales team needs to know what the busiest hours of the
# day are (i.e., the days and times with the most orders) in order to schedule ads at
# times when there are fewer orders.

## Line chart

ords_prods_customer['order_hour_of_day'].value_counts().sort_index().plot.bar(color = 'purple',edgecolor='black')
plt.title('Busy times in a day', 
          pad = 25,
          fontsize=15,
         fontweight=2);
plt.suptitle('(by order count)',
            x=0.5,
            y=0.93)
plt.xlabel('Hours of the day')
plt.ylabel('Total orders');

plt.savefig(os.path.join(path, '04 Analysis','Visualizations', 'busy_hours_in_a_day.png'))

# %%
## Key Question 2:

## They also want to know whether there are particular times of the day when people
## spend the most money, as this might inform the type of products they advertise at
# these times.

df_price_hour = ords_prods_customer.groupby('order_hour_of_day')['prices'].mean().reset_index()

sns.barplot(data = df_price_hour, x = 'order_hour_of_day', y = 'prices')
plt.xlabel('Hours of the day')
plt.ylabel('Average Ordering Prices')
plt.title('When do people spend most of their money');

plt.savefig(os.path.join(path, '04 Analysis','Visualizations', 'hourly_average_spend.png'),bbox_inches='tight')

# %%
## Key Question 3

# Instacart has a lot of products with different price tags. Marketing and sales want to
# use simpler price range groupings to help direct their efforts.

# Creating groups based on the prices and creating pie chart
# 0.25     4.2
# 0.50     7.4
# 0.75    11.3
ords_prods_customer['prices'].quantile([0.25, 0.5, 0.75])

## Creating four price groups

ords_prods_customer.loc[(ords_prods_customer['prices'] < 4.2), 'price_category'] = 'low_price'
ords_prods_customer.loc[(ords_prods_customer['prices'] >= 4.2) & (ords_prods_customer['prices'] < 7.4), 'price_category'] = 'medium_price'
ords_prods_customer.loc[(ords_prods_customer['prices'] >=  7.4) & (ords_prods_customer['prices'] < 11.3), 'price_category'] = 'expensive_price'
ords_prods_customer.loc[(ords_prods_customer['prices'] >= 11.3), 'price_category'] = 'very_expensive_price'

## 

ords_prods_customer['price_category'].value_counts()
# Out:
# price_category
# medium_price            8264810
# expensive_price         8136955
# very_expensive_price    8112236
# low_price               7890855
# Name: count, dtype: int64

# %%
## Key Question 4

## Are there certain types of products that are more popular than others? The marketing
## and sales teams want to know which departments have the highest frequency of
## product orders.

department_order_counts = ords_prods_customer.groupby('department_category')['order_id'].count().reset_index()
department_order_counts.columns = ['department', 'order_count']
department_order_counts = department_order_counts.sort_values('order_count', ascending=False)

department_order_counts.plot(kind='bar', x='department', y='order_count', 
                             edgecolor='black', legend=False)

plt.xticks(rotation=45)
plt.title('Most Popular Products', pad=40, fontsize=15, fontweight='bold')
plt.xlabel('Department Category')
plt.ylabel('Order Count')

plt.savefig(os.path.join(path, '04 Analysis','Visualizations', 'most_popular_products.png'),bbox_inches='tight')

# %% [markdown]
# ### Answering Marketing Department Questions

# %%
## What’s the distribution among users in regards to their brand loyalty (i.e., how
## often do they return to Instacart)?

# Creating the number of returned orders based on the loyalty flag and user

user_order_counts = ords_prods_customer.groupby(['user_id', 'loyalty_flag'])['order_id'].nunique().reset_index()
user_order_counts.columns = ['user_id', 'loyalty_flag', 'order_count']

# Aggregate order counts by loyalty_flag
loyalty_distribution = user_order_counts.groupby('loyalty_flag')['user_id'].count().reset_index()
loyalty_distribution.columns = ['loyalty_flag', 'user_count']
color = ['red', 'blue', 'green']
# Plot a bar chart
plt.bar(loyalty_distribution['loyalty_flag'], loyalty_distribution['user_count'], color = color, edgecolor = 'black')
plt.xlabel("Loyalty Category")
plt.ylabel("Number of Users")
plt.title("User Distribution by Brand Loyalty", pad = 30);

plt.savefig(os.path.join(path, '04 Analysis','Visualizations', 'user_dist_by_brand_loyalty.png'),bbox_inches='tight')

# %%
## Are there differences in ordering habits based on a customer’s loyalty status?

order_loyalty = ords_prods_customer.groupby('loyalty_flag')['order_id'].count().reset_index()

plt.bar(order_loyalty['loyalty_flag'], order_loyalty['order_id'], color = color, edgecolor = 'black')
plt.xlabel("Loyalty Category")
plt.ylabel("Number of Orders")
plt.title("Total orders by Brand Loyalty", pad = 30);

plt.savefig(os.path.join(path, '04 Analysis','Visualizations', 'total_orders_by_brand_loyalty.png'))

# %%
## Are there differences in ordering habits based on a customer’s region?

order_region = ords_prods_customer.groupby('region')['order_id'].count().reset_index()
order_region

plt.pie(order_region['order_id'], labels=order_region['region'], shadow = True, 
        autopct='%.1f%%',
        colors = colors,
        labeldistance=1.1)
plt.title('Ordering pattern - Region Wise', 
          pad = 30,
         fontsize=15,
         fontweight=2);

plt.savefig(os.path.join(path, '04 Analysis','Visualizations', 'order_pattern_region_wise.png'),bbox_inches='tight')

# %%
## Is there a connection between age and family status in terms of ordering habits?

df_age_family = ords_prods_customer.groupby(['age_category', 'dependant_category'])['prices'].mean()

colors = ['red', 'blue', 'green', 'orange', 'purple', 'cyan', 'violet', 'pink']

df_age_family.plot.bar(stacked = False, color = colors, edgecolor = 'black')
plt.xticks(rotation = 45)
plt.xlabel("Age and Family Status Categories")
plt.ylabel("Average Price Spent")
plt.title("Average Price of the Orders - by Age and Dependents Category", pad = 30);

plt.savefig(os.path.join(path, '04 Analysis','Visualizations', 'average_price_age_dependent_cat.png'),bbox_inches='tight')

# %%
## What different classifications does the demographic information suggest? Age? Income? Certain types of goods? Family status?
## What differences can you find in ordering habits of different customer
## profiles? Consider the price of orders, the frequency of orders, the products
## customers are ordering, and anything else you can think of.

demographic_pattern = ords_prods_customer.groupby(['age_category', 'income_category', 'dependant_category'])['order_id'].count().reset_index().sort_values(by='order_id', ascending= False)

demographic_pattern
# Out:
#    age_category    income_category dependant_category  order_id
# 8       elderly        high income             family   3054244
# 16   middle age        high income             family   2915584
# 10      elderly  higher mid income             family   2777401
# 18   middle age  higher mid income             family   2727499
# 4         adult         low income             family   2624831
# 6         adult   lower mid income             family   2597087
# 30  young adult   lower mid income             family   1277945
# 28  young adult         low income             family   1223543
# 20   middle age         low income             family   1191018
# 22   middle age   lower mid income             family   1162645
# 14      elderly   lower mid income             family   1056638
# 12      elderly         low income             family   1039963
# 9       elderly        high income             single   1012894
# 17   middle age        high income             single    992123
# 11      elderly  higher mid income             single    943807
# 19   middle age  higher mid income             single    898884
# 5         adult         low income             single    892454
# 7         adult   lower mid income             single    869355
# 31  young adult   lower mid income             single    400033
# 29  young adult         low income             single    398943
# 21   middle age         low income             single    391995
# 2         adult  higher mid income             family    384213
# 23   middle age   lower mid income             single    378080
# 15      elderly   lower mid income             single    359424
# 13      elderly         low income             single    338465
# 26  young adult  higher mid income             family    176887
# 3         adult  higher mid income             single    138886
# 0         adult        high income             family     66808
# 27  young adult  higher mid income             single     53823
# 24  young adult        high income             family     31048
# 1         adult        high income             single     17557
# 25  young adult        high income             single     10779

# %%
## Visualization

sns.barplot(data=demographic_pattern, x='age_category', y='order_id', hue='income_category', errorbar=None)

plt.title('Order Distribution by Age and Income Category')
plt.xlabel('Age Category')
plt.ylabel('Number of Orders')
plt.legend(title='Income Category', bbox_to_anchor=(1, 1))
plt.xticks(rotation=45);

plt.savefig(os.path.join(path, '04 Analysis','Visualizations', 'order_by_age_income_cat.png'),bbox_inches='tight')

# %%
demographic_pattern_2 = ords_prods_customer.groupby(['age_category', 'income_category', 'department_category'])['order_id'].count().reset_index().sort_values(by='order_id', ascending= False)

pd.set_option('display.max_rows', None)
demographic_pattern_2
# Out:
#     age_category    income_category department_category  order_id
# 49       elderly        high income             produce   1208106
# 89    middle age        high income             produce   1159288
# 59       elderly  higher mid income             produce   1118363
# 99    middle age  higher mid income             produce   1091276
# 39         adult   lower mid income             produce   1043576
# 29         adult         low income             produce   1004789
# 159  young adult   lower mid income             produce    508328
# 149  young adult         low income             produce    459493
# 119   middle age   lower mid income             produce    458998
# 79       elderly   lower mid income             produce    426306
# 109   middle age         low income             produce    405680
# 69       elderly         low income             produce    343842
# 42       elderly        high income           beverages    326321
# 82    middle age        high income           beverages    308826
# 22         adult         low income           beverages    306205
# 52       elderly  higher mid income           beverages    290026
# 92    middle age  higher mid income           beverages    287841
# 45       elderly        high income              frozen    286068
# 85    middle age        high income              frozen    272904
# 32         adult   lower mid income           beverages    268032
# 55       elderly  higher mid income              frozen    258043
# 95    middle age  higher mid income              frozen    251631
# 35         adult   lower mid income              frozen    241123
# 25         adult         low income              frozen    236017
# 102   middle age         low income           beverages    171246
# 19         adult  higher mid income             produce    157774
# 62       elderly         low income           beverages    156276
# 41       elderly        high income              bakery    151762
# 81    middle age        high income              bakery    145284
# 142  young adult         low income           beverages    142813
# 51       elderly  higher mid income              bakery    135835
# 91    middle age  higher mid income              bakery    133726
# 152  young adult   lower mid income           beverages    128140
# 31         adult   lower mid income              bakery    126616
# 21         adult         low income              bakery    125223
# 112   middle age   lower mid income           beverages    123050
# 155  young adult   lower mid income              frozen    114975
# 145  young adult         low income              frozen    112101
# 44       elderly        high income     dry goods pasta    111623
# 72       elderly   lower mid income           beverages    110377
# 84    middle age        high income     dry goods pasta    109039
# 115   middle age   lower mid income              frozen    108249
# 54       elderly  higher mid income     dry goods pasta    104297
# 105   middle age         low income              frozen    101972
# 94    middle age  higher mid income     dry goods pasta    100843
# 75       elderly   lower mid income              frozen    100445
# 34         adult   lower mid income     dry goods pasta     96315
# 65       elderly         low income              frozen     89706
# 24         adult         low income     dry goods pasta     88929
# 139  young adult  higher mid income             produce     67773
# 151  young adult   lower mid income              bakery     60893
# 141  young adult         low income              bakery     57409
# 111   middle age   lower mid income              bakery     55386
# 71       elderly   lower mid income              bakery     51664
# 101   middle age         low income              bakery     51101
# 154  young adult   lower mid income     dry goods pasta     46918
# 61       elderly         low income              bakery     43450
# 114   middle age   lower mid income     dry goods pasta     42944
# 144  young adult         low income     dry goods pasta     41874
# 12         adult  higher mid income           beverages     40681
# 74       elderly   lower mid income     dry goods pasta     39257
# 15         adult  higher mid income              frozen     35523
# 46       elderly        high income       international     34195
# 86    middle age        high income       international     33589
# 104   middle age         low income     dry goods pasta     32598
# 56       elderly  higher mid income       international     31639
# 96    middle age  higher mid income       international     30974
# 36         adult   lower mid income       international     29710
# 26         adult         low income       international     28259
# 64       elderly         low income     dry goods pasta     26948
# 80    middle age        high income             alcohol     20481
# 40       elderly        high income             alcohol     19170
# 11         adult  higher mid income              bakery     18833
# 9          adult        high income             produce     18120
# 132  young adult  higher mid income           beverages     17382
# 20         adult         low income             alcohol     16156
# 50       elderly  higher mid income             alcohol     16033
# 90    middle age  higher mid income             alcohol     15981
# 135  young adult  higher mid income              frozen     15804
# 30         adult   lower mid income             alcohol     15756
# 156  young adult   lower mid income       international     14729
# 14         adult  higher mid income     dry goods pasta     14721
# 116   middle age   lower mid income       international     13712
# 146  young adult         low income       international     13185
# 48       elderly        high income                pets     13117
# 88    middle age        high income                pets     12402
# 76       elderly   lower mid income       international     12218
# 58       elderly  higher mid income                pets     11351
# 98    middle age  higher mid income                pets     10964
# 106   middle age         low income       international     10598
# 28         adult         low income                pets     10002
# 38         adult   lower mid income                pets      9562
# 131  young adult  higher mid income              bakery      9007
# 66       elderly         low income       international      8887
# 140  young adult         low income             alcohol      8304
# 100   middle age         low income             alcohol      7884
# 150  young adult   lower mid income             alcohol      7620
# 129  young adult        high income             produce      7577
# 60       elderly         low income             alcohol      7403
# 2          adult        high income           beverages      7238
# 5          adult        high income              frozen      6693
# 134  young adult  higher mid income     dry goods pasta      6616
# 110   middle age   lower mid income             alcohol      5928
# 70       elderly   lower mid income             alcohol      5927
# 148  young adult         low income                pets      5480
# 158  young adult   lower mid income                pets      4852
# 118   middle age   lower mid income                pets      4782
# 16         adult  higher mid income       international      4695
# 47       elderly        high income               other      4570
# 87    middle age        high income               other      4279
# 1          adult        high income              bakery      4242
# 78       elderly   lower mid income                pets      4190
# 97    middle age  higher mid income               other      4061
# 57       elderly  higher mid income               other      4033
# 43       elderly        high income                bulk      4016
# 108   middle age         low income                pets      3946
# 37         adult   lower mid income               other      3929
# 53       elderly  higher mid income                bulk      3872
# 23         adult         low income                bulk      3844
# 27         adult         low income               other      3814
# 33         adult   lower mid income                bulk      3792
# 83    middle age        high income                bulk      3772
# 93    middle age  higher mid income                bulk      3677
# 122  young adult        high income           beverages      3669
# 125  young adult        high income              frozen      3489
# 68       elderly         low income                pets      3472
# 4          adult        high income     dry goods pasta      2462
# 10         adult  higher mid income             alcohol      2453
# 103   middle age         low income                bulk      2202
# 121  young adult        high income              bakery      1997
# 0          adult        high income             alcohol      1967
# 147  young adult         low income               other      1922
# 63       elderly         low income                bulk      1890
# 153  young adult   lower mid income                bulk      1856
# 136  young adult  higher mid income       international      1828
# 157  young adult   lower mid income               other      1811
# 107   middle age         low income               other      1786
# 117   middle age   lower mid income               other      1753
# 143  young adult         low income                bulk      1752
# 18         adult  higher mid income                pets      1638
# 113   middle age   lower mid income                bulk      1629
# 77       elderly   lower mid income               other      1556
# 67       elderly         low income               other      1543
# 73       elderly   lower mid income                bulk      1513
# 120  young adult        high income             alcohol      1375
# 138  young adult  higher mid income                pets      1346
# 130  young adult  higher mid income             alcohol      1258
# 124  young adult        high income     dry goods pasta      1243
# 6          adult        high income       international       704
# 17         adult  higher mid income               other       650
# 13         adult  higher mid income                bulk       484
# 8          adult        high income                pets       365
# 126  young adult        high income       international       331
# 137  young adult  higher mid income               other       276
# 133  young adult  higher mid income                bulk       259
# 128  young adult        high income                pets       247
# 7          adult        high income               other       217
# 127  young adult        high income               other        91
# 3          adult        high income                bulk        10
# 123  young adult        high income                bulk         5

# %%
## Loyalty profile groupings


df_profile_loyalty = pd.crosstab(ords_prods_customer['customer_profile'], ords_prods_customer['loyalty_flag'], normalize = True)
df_profile_loyalty

df_profile_loyalty.plot.bar(stacked=False, edgecolor = 'black')
plt.title('Distribution of Loyalty and Customer Profiles', 
          pad = 40,
          fontsize=15,
          fontweight=2);
plt.ylabel('Distribution percentage')
plt.xlabel('Customer Profile')
plt.xticks(rotation = 45);

plt.savefig(os.path.join(path, '04 Analysis','Visualizations', 'loyalty_and_customer_profile.png'), bbox_inches='tight')

# %%
df_profile_spender = pd.crosstab(ords_prods_customer['spending_flag'], ords_prods_customer['loyalty_flag'], normalize = True)
df_profile_spender

df_profile_spender.plot.bar(stacked=False, edgecolor = 'black')
plt.title('Distribution of Loyalty and Customer Profiles', 
          pad = 40,
          fontsize=15,
          fontweight=2);
plt.ylabel('Distribution percentage')
plt.xlabel('Spender Category')
plt.xticks(rotation = 45);

plt.savefig(os.path.join(path, '04 Analysis','Visualizations', 'loyalty_and_spender.png'), bbox_inches='tight')

# %%
## Loyalty by income group

df_profile_income = pd.crosstab(ords_prods_customer['income_category'], ords_prods_customer['loyalty_flag'])
df_profile_income

df_profile_income.plot.bar(stacked=False, edgecolor = 'black')
plt.title('Distribution of Loyalty and Customer Profiles', 
          pad = 40,
          fontsize=15,
          fontweight=2);
plt.ylabel('Distribution percentage')
plt.xlabel('Spender Category')
plt.xticks(rotation = 45);

plt.savefig(os.path.join(path, '04 Analysis','Visualizations', 'loyalty_and_income.png'), bbox_inches='tight')

# %%
df_profile_income = pd.crosstab(ords_prods_customer['income_category'], ords_prods_customer['loyalty_flag'])
df_profile_income
# Out:
# loyalty_flag       Loyal customer  New customer  Regular customer
# income_category
# high income               2575561       1506799           4018677
# higher mid income         2610705       1510039           3980656
# low income                2469238       1738743           3893231
# lower mid income          2628589       1488406           3984212

# %%
df_profile_spender = pd.crosstab(ords_prods_customer['spending_flag'], ords_prods_customer['loyalty_flag'])
df_profile_spender

df_profile_spender.plot.bar(stacked=False, edgecolor = 'black')
plt.title('Distribution of Loyalty and Customer Profiles', 
          pad = 40,
          fontsize=15,
          fontweight=2);
plt.ylabel('Distribution percentage')
plt.xlabel('Spender Category')
plt.xticks(rotation = 45);

plt.savefig(os.path.join(path, '04 Analysis','Visualizations', 'loyalty_and_spender_count.png'), bbox_inches='tight')

# %%
ords_prods_customer['spending_flag'].value_counts().plot.bar();
# Out:
# <Axes: xlabel='spending_flag'>
